# %% [markdown]
# # hard voting

# %%
import numpy as np
from sklearn import metrics
from typing import Dict

# %%
np.random.seed(42)

# %%
labels = np.load("outputs/animals_10-test_labels.npy")

# %%
preds_paths = {  # 已按表现降序
    "vit": "outputs/vit_aug/vit_b_16-animals_10_aug-250103-1502-test_preds.npy",  # 98.61
    "densenet": "outputs/densenet_aug/densenet201-animals_10_aug-250103-1500-test_preds.npy",  # 98.44
    "resnet": "outputs/resnet_aug/resnet152-animals_10_aug-250103-1619-test_preds.npy",  # 98.28
    "vgg": "outputs/vgg_aug/vgg19_bn-animals_10_aug-250103-1622-test_preds.npy",  # 97.83
    "googlenet": "outputs/googlenet_aug/googlenet-animals_10_aug-250103-1617-test_preds.npy",  # 95.83
    "alexnet": "outputs/alexnet_aug/alexnet-animals_10_aug-250103-1501-test_preds.npy",  # 91.67
}

# %%
preds_dict = {key: np.load(preds_paths[key]) for key in preds_paths.keys()}

# %%
def evaluate(labels: np.ndarray, preds: np.ndarray) -> Dict[str, float]:
    acc = round(metrics.accuracy_score(labels, preds), 4)
    macro_f1 = round(metrics.f1_score(labels, preds, labels=range(6), average="macro"), 4)
    return {"acc": acc, "f1": macro_f1}

# %%
def hard_voting(preds_all: np.ndarray) -> np.ndarray:
    preds = []

    for i in range(preds_all.shape[1]):
        votes = preds_all[:, i]
        count = np.bincount(votes)
        max_count = np.max(count)
        pred_tie = np.array(np.where(count == max_count)).flatten()
        pred = np.random.choice(pred_tie)
        preds.append(pred)
    preds = np.array(preds)
    return preds

# %%
def dfs(n: int, begin: int = 0, k: int = 0):
    if k == n:
        preds_all = np.array(select_values)
        preds = hard_voting(preds_all)
        print(select_names, evaluate(labels, preds))
        return
    for i in range(begin, num):
        if vis[i]:
            continue
        select_names.append(keys[i])
        select_values.append(values[i])
        vis[i] = True
        dfs(n, i + 1, k + 1)
        select_names.pop()
        select_values.pop()
        vis[i] = False

# %%
def grid_search(maxn: int) -> None:
    for n in range(3, maxn + 1):
        dfs(n)

# %%
num = len(preds_dict)
vis = [False] * num
keys = list(preds_dict.keys())
values = list(preds_dict.values())
select_names = []
select_values = []
grid_search(maxn=num)
# Out:
# ['vit', 'densenet', 'resnet'] {'acc': 0.9867, 'f1': 0.9867}
# ['vit', 'densenet', 'vgg'] {'acc': 0.985, 'f1': 0.985}
# ['vit', 'densenet', 'googlenet'] {'acc': 0.985, 'f1': 0.985}
# ['vit', 'densenet', 'alexnet'] {'acc': 0.9822, 'f1': 0.9822}
# ['vit', 'resnet', 'vgg'] {'acc': 0.9856, 'f1': 0.9856}
# ['vit', 'resnet', 'googlenet'] {'acc': 0.985, 'f1': 0.985}
# ['vit', 'resnet', 'alexnet'] {'acc': 0.9833, 'f1': 0.9833}
# ['vit', 'vgg', 'googlenet'] {'acc': 0.9817, 'f1': 0.9817}
# ['vit', 'vgg', 'alexnet'] {'acc': 0.9806, 'f1': 0.9806}
# ['vit', 'googlenet', 'alexnet'] {'acc': 0.975, 'f1': 0.975}
# ['densenet', 'resnet', 'vgg'] {'acc': 0.9844, 'f1': 0.9844}
# ['densenet', 'resnet', 'googlenet'] {'acc': 0.9828, 'f1': 0.9828}
# ['densenet', 'resnet', 'alexnet'] {'acc': 0.9817, 'f1': 0.9817}
# ['densenet', 'vgg', 'googlenet'] {'acc': 0.9817, 'f1': 0.9817}
# ['densenet', 'vgg', 'alexnet'] {'acc': 0.9817, 'f1': 0.9817}
# ['densenet', 'googlenet', 'alexnet'] {'acc': 0.9733, 'f1': 0.9733}
# ['resnet', 'vgg', 'googlenet'] {'acc': 0.98, 'f1': 0.98}
# ['resnet', 'vgg', 'alexnet'] {'acc': 0.9783, 'f1': 0.9783}
# ['resnet', 'googlenet', 'alexnet'] {'acc': 0.9711, 'f1': 0.9711}
# ['vgg', 'googlenet', 'alexnet'] {'acc': 0.9689, 'f1': 0.9689}
# ['vit', 'densenet', 'resnet', 'vgg'] {'acc': 0.9867, 'f1': 0.9867}
# ['vit', 'densenet', 'resnet', 'googlenet'] {'acc': 0.9844, 'f1': 0.9845}
# ['vit', 'densenet', 'resnet', 'alexnet'] {'acc': 0.985, 'f1': 0.985}
# ['vit', 'densenet', 'vgg', 'googlenet'] {'acc': 0.9839, 'f1': 0.9839}
# ['vit', 'densenet', 'vgg', 'alexnet'] {'acc': 0.9833, 'f1': 0.9833}
# ['vit', 'densenet', 'googlenet', 'alexnet'] {'acc': 0.9811, 'f1': 0.9811}
# ['vit', 'resnet', 'vgg', 'googlenet'] {'acc': 0.9828, 'f1': 0.9828}
# ['vit', 'resnet', 'vgg', 'alexnet'] {'acc': 0.9844, 'f1': 0.9844}
# ['vit', 'resnet', 'googlenet', 'alexnet'] {'acc': 0.9783, 'f1': 0.9783}
# ['vit', 'vgg', 'googlenet', 'alexnet'] {'acc': 0.9767, 'f1': 0.9767}
# ['densenet', 'resnet', 'vgg', 'googlenet'] {'acc': 0.9811, 'f1': 0.9811}
# ['densenet', 'resnet', 'vgg', 'alexnet'] {'acc': 0.9811, 'f1': 0.9811}
# ['densenet', 'resnet', 'googlenet', 'alexnet'] {'acc': 0.9789, 'f1': 0.9789}
# ['densenet', 'vgg', 'googlenet', 'alexnet'] {'acc': 0.9761, 'f1': 0.9761}
# ['resnet', 'vgg', 'googlenet', 'alexnet'] {'acc': 0.9744, 'f1': 0.9745}
# ['vit', 'densenet', 'resnet', 'vgg', 'googlenet'] {'acc': 0.985, 'f1': 0.985}
# ['vit', 'densenet', 'resnet', 'vgg', 'alexnet'] {'acc': 0.985, 'f1': 0.985}
# ['vit', 'densenet', 'resnet', 'googlenet', 'alexnet'] {'acc': 0.9828, 'f1': 0.9828}
# ['vit', 'densenet', 'vgg', 'googlenet', 'alexnet'] {'acc': 0.9833, 'f1': 0.9833}
# ['vit', 'resnet', 'vgg', 'googlenet', 'alexnet'] {'acc': 0.9822, 'f1': 0.9822}
# ['densenet', 'resnet', 'vgg', 'googlenet', 'alexnet'] {'acc': 0.9839, 'f1': 0.9839}
# ['vit', 'densenet', 'resnet', 'vgg', 'googlenet', 'alexnet'] {'acc': 0.9844, 'f1': 0.9844}

# %% [markdown]
# 实验结果表明用多个表现同样尽可能好的分类器 hard voting 往往会带来更好的表现
# 表现明显更差的分类器往往会拉低表现最好分类器的表现，尽管有时并不一定，如果能带来新的有价值的不同视角，有时也许可能提高表现
# 实验中组合的最好结果是：
# vit + densenet + resnet，98.67
# vit + densenet + resnet + vgg，98.67

# %% [markdown]
# 基于上述结果，三到四个分类器组合就是充足的，以及考虑到我们的 fusion 方法已经用到 densenet、vit。所以尝试对 fusion 方法和其他方法的 voting 组合如下

# %%
preds_paths = {  # 已按表现降序
    "glip": "outputs/glip/glip-animals_10_aug-250104-1413-test_preds.npy",  # 99.06
    "point_fusion": "outputs/point_fusion/point_fusion-animals_10_aug-250103-1954-test_preds.npy",  # 98.67
    "vit": "outputs/vit_aug/vit_b_16-animals_10_aug-250103-1502-test_preds.npy",  # 98.61
    "decision_fusion": "outputs/decision_fusion/decision_fusion-animals_10_aug-250105-1338-test_preds.npy",  # 98.61
    "wfcg": "outputs/wfcg/wfcg-animals_10_aug-250105-1523-test_preds.npy",  # 98.50
    "densenet": "outputs/densenet_aug/densenet201-animals_10_aug-250103-1500-test_preds.npy",  # 98.44
    "resnet": "outputs/resnet_aug/resnet152-animals_10_aug-250103-1619-test_preds.npy",  # 98.28
    "mvc": "outputs/mvc/mvc-animals_10_aug-250105-2233-test_preds.npy",  # 98.17
    "vgg": "outputs/vgg_aug/vgg19_bn-animals_10_aug-250103-1622-test_preds.npy",  # 97.83
}

# %%
preds_dict = {key: np.load(preds_paths[key]) for key in preds_paths.keys()}
num = len(preds_dict)
vis = [False] * num
keys = list(preds_dict.keys())
values = list(preds_dict.values())
select_names = []
select_values = []
grid_search(maxn=num)
# Out:
# ['glip', 'point_fusion', 'vit'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'point_fusion', 'decision_fusion'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'point_fusion', 'wfcg'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'point_fusion', 'densenet'] {'acc': 0.9906, 'f1': 0.9906}
# ['glip', 'point_fusion', 'resnet'] {'acc': 0.9889, 'f1': 0.9889}
# ['glip', 'point_fusion', 'mvc'] {'acc': 0.9872, 'f1': 0.9872}
# ['glip', 'point_fusion', 'vgg'] {'acc': 0.9894, 'f1': 0.9895}
# ['glip', 'vit', 'decision_fusion'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'vit', 'wfcg'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'vit', 'densenet'] {'acc': 0.99, 'f1': 0.99}
# ['glip', 'vit', 'resnet'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'vit', 'mvc'] {'acc': 0.9861, 'f1': 0.9861}
# ['glip', 'vit', 'vgg'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'decision_fusion', 'wfcg'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'decision_fusion', 'densenet'] {'acc': 0.99, 'f1': 0.99}
# ['glip', 'decision_fusion', 'resnet'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'decision_fusion', 'mvc'] {'acc': 0.9872, 'f1': 0.9872}
# ['glip', 'decision_fusion', 'vgg'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'wfcg', 'densenet'] {'acc': 0.9889, 'f1': 0.9889}
# ['glip', 'wfcg', 'resnet'] {'acc': 0.9872, 'f1': 0.9872}
# ['glip', 'wfcg', 'mvc'] {'acc': 0.9867, 'f1': 0.9867}
# ['glip', 'wfcg', 'vgg'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'densenet', 'resnet'] {'acc': 0.9889, 'f1': 0.9889}
# ['glip', 'densenet', 'mvc'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'densenet', 'vgg'] {'acc': 0.9867, 'f1': 0.9867}
# ['glip', 'resnet', 'mvc'] {'acc': 0.9867, 'f1': 0.9867}
# ['glip', 'resnet', 'vgg'] {'acc': 0.9867, 'f1': 0.9867}
# ['glip', 'mvc', 'vgg'] {'acc': 0.9872, 'f1': 0.9872}
# ['point_fusion', 'vit', 'decision_fusion'] {'acc': 0.9872, 'f1': 0.9872}
# ['point_fusion', 'vit', 'wfcg'] {'acc': 0.9872, 'f1': 0.9872}
# ['point_fusion', 'vit', 'densenet'] {'acc': 0.9883, 'f1': 0.9883}
# ['point_fusion', 'vit', 'resnet'] {'acc': 0.9889, 'f1': 0.9889}
# ['point_fusion', 'vit', 'mvc'] {'acc': 0.9867, 'f1': 0.9867}
# ['point_fusion', 'vit', 'vgg'] {'acc': 0.9878, 'f1': 0.9878}
# ['point_fusion', 'decision_fusion', 'wfcg'] {'acc': 0.9872, 'f1': 0.9872}
# ['point_fusion', 'decision_fusion', 'densenet'] {'acc': 0.9889, 'f1': 0.9889}
# ['point_fusion', 'decision_fusion', 'resnet'] {'acc': 0.9889, 'f1': 0.9889}
# ['point_fusion', 'decision_fusion', 'mvc'] {'acc': 0.9872, 'f1': 0.9872}
# ['point_fusion', 'decision_fusion', 'vgg'] {'acc': 0.9878, 'f1': 0.9878}
# ['point_fusion', 'wfcg', 'densenet'] {'acc': 0.9878, 'f1': 0.9878}
# ['point_fusion', 'wfcg', 'resnet'] {'acc': 0.9867, 'f1': 0.9867}
# ['point_fusion', 'wfcg', 'mvc'] {'acc': 0.9856, 'f1': 0.9856}
# ['point_fusion', 'wfcg', 'vgg'] {'acc': 0.9872, 'f1': 0.9872}
# ['point_fusion', 'densenet', 'resnet'] {'acc': 0.9872, 'f1': 0.9872}
# ['point_fusion', 'densenet', 'mvc'] {'acc': 0.9878, 'f1': 0.9878}
# ['point_fusion', 'densenet', 'vgg'] {'acc': 0.985, 'f1': 0.985}
# ['point_fusion', 'resnet', 'mvc'] {'acc': 0.9872, 'f1': 0.9872}
# ['point_fusion', 'resnet', 'vgg'] {'acc': 0.9856, 'f1': 0.9856}
# ['point_fusion', 'mvc', 'vgg'] {'acc': 0.9861, 'f1': 0.9861}
# ['vit', 'decision_fusion', 'wfcg'] {'acc': 0.9878, 'f1': 0.9878}
# ['vit', 'decision_fusion', 'densenet'] {'acc': 0.9872, 'f1': 0.9872}
# ['vit', 'decision_fusion', 'resnet'] {'acc': 0.9878, 'f1': 0.9878}
# ['vit', 'decision_fusion', 'mvc'] {'acc': 0.9867, 'f1': 0.9867}
# ['vit', 'decision_fusion', 'vgg'] {'acc': 0.9861, 'f1': 0.9861}
# ['vit', 'wfcg', 'densenet'] {'acc': 0.9872, 'f1': 0.9872}
# ['vit', 'wfcg', 'resnet'] {'acc': 0.9861, 'f1': 0.9861}
# ['vit', 'wfcg', 'mvc'] {'acc': 0.9856, 'f1': 0.9856}
# ['vit', 'wfcg', 'vgg'] {'acc': 0.9861, 'f1': 0.9861}
# ['vit', 'densenet', 'resnet'] {'acc': 0.9861, 'f1': 0.9861}
# ['vit', 'densenet', 'mvc'] {'acc': 0.9861, 'f1': 0.9861}
# ['vit', 'densenet', 'vgg'] {'acc': 0.9856, 'f1': 0.9855}
# ['vit', 'resnet', 'mvc'] {'acc': 0.9856, 'f1': 0.9856}
# ['vit', 'resnet', 'vgg'] {'acc': 0.9856, 'f1': 0.9856}
# ['vit', 'mvc', 'vgg'] {'acc': 0.985, 'f1': 0.985}
# ['decision_fusion', 'wfcg', 'densenet'] {'acc': 0.9872, 'f1': 0.9872}
# ['decision_fusion', 'wfcg', 'resnet'] {'acc': 0.9856, 'f1': 0.9856}
# ['decision_fusion', 'wfcg', 'mvc'] {'acc': 0.9867, 'f1': 0.9867}
# ['decision_fusion', 'wfcg', 'vgg'] {'acc': 0.9856, 'f1': 0.9856}
# ['decision_fusion', 'densenet', 'resnet'] {'acc': 0.9872, 'f1': 0.9872}
# ['decision_fusion', 'densenet', 'mvc'] {'acc': 0.9872, 'f1': 0.9872}
# ['decision_fusion', 'densenet', 'vgg'] {'acc': 0.9839, 'f1': 0.9839}
# ['decision_fusion', 'resnet', 'mvc'] {'acc': 0.9867, 'f1': 0.9867}
# ['decision_fusion', 'resnet', 'vgg'] {'acc': 0.985, 'f1': 0.985}
# ['decision_fusion', 'mvc', 'vgg'] {'acc': 0.9844, 'f1': 0.9845}
# ['wfcg', 'densenet', 'resnet'] {'acc': 0.9867, 'f1': 0.9867}
# ['wfcg', 'densenet', 'mvc'] {'acc': 0.9867, 'f1': 0.9867}
# ['wfcg', 'densenet', 'vgg'] {'acc': 0.985, 'f1': 0.985}
# ['wfcg', 'resnet', 'mvc'] {'acc': 0.9856, 'f1': 0.9856}
# ['wfcg', 'resnet', 'vgg'] {'acc': 0.9856, 'f1': 0.9856}
# ['wfcg', 'mvc', 'vgg'] {'acc': 0.9844, 'f1': 0.9845}
# ['densenet', 'resnet', 'mvc'] {'acc': 0.9867, 'f1': 0.9867}
# ['densenet', 'resnet', 'vgg'] {'acc': 0.9839, 'f1': 0.9839}
# ['densenet', 'mvc', 'vgg'] {'acc': 0.9839, 'f1': 0.9839}
# ['resnet', 'mvc', 'vgg'] {'acc': 0.9839, 'f1': 0.9839}
# ['glip', 'point_fusion', 'vit', 'decision_fusion'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'point_fusion', 'vit', 'wfcg'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'point_fusion', 'vit', 'densenet'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'point_fusion', 'vit', 'resnet'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'point_fusion', 'vit', 'mvc'] {'acc': 0.9872, 'f1': 0.9872}
# ['glip', 'point_fusion', 'vit', 'vgg'] {'acc': 0.9889, 'f1': 0.9889}
# ['glip', 'point_fusion', 'decision_fusion', 'wfcg'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'point_fusion', 'decision_fusion', 'densenet'] {'acc': 0.9894, 'f1': 0.9895}
# ['glip', 'point_fusion', 'decision_fusion', 'resnet'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'point_fusion', 'decision_fusion', 'mvc'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'point_fusion', 'decision_fusion', 'vgg'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'point_fusion', 'wfcg', 'densenet'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'point_fusion', 'wfcg', 'resnet'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'point_fusion', 'wfcg', 'mvc'] {'acc': 0.9872, 'f1': 0.9872}
# ['glip', 'point_fusion', 'wfcg', 'vgg'] {'acc': 0.9889, 'f1': 0.9889}
# ['glip', 'point_fusion', 'densenet', 'resnet'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'point_fusion', 'densenet', 'mvc'] {'acc': 0.9894, 'f1': 0.9895}
# ['glip', 'point_fusion', 'densenet', 'vgg'] {'acc': 0.9889, 'f1': 0.9889}
# ['glip', 'point_fusion', 'resnet', 'mvc'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'point_fusion', 'resnet', 'vgg'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'point_fusion', 'mvc', 'vgg'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'vit', 'decision_fusion', 'wfcg'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'vit', 'decision_fusion', 'densenet'] {'acc': 0.9889, 'f1': 0.9889}
# ['glip', 'vit', 'decision_fusion', 'resnet'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'vit', 'decision_fusion', 'mvc'] {'acc': 0.9872, 'f1': 0.9872}
# ['glip', 'vit', 'decision_fusion', 'vgg'] {'acc': 0.9867, 'f1': 0.9867}
# ['glip', 'vit', 'wfcg', 'densenet'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'vit', 'wfcg', 'resnet'] {'acc': 0.9872, 'f1': 0.9872}
# ['glip', 'vit', 'wfcg', 'mvc'] {'acc': 0.9867, 'f1': 0.9867}
# ['glip', 'vit', 'wfcg', 'vgg'] {'acc': 0.9872, 'f1': 0.9872}
# ['glip', 'vit', 'densenet', 'resnet'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'vit', 'densenet', 'mvc'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'vit', 'densenet', 'vgg'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'vit', 'resnet', 'mvc'] {'acc': 0.9867, 'f1': 0.9867}
# ['glip', 'vit', 'resnet', 'vgg'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'vit', 'mvc', 'vgg'] {'acc': 0.9856, 'f1': 0.9856}
# ['glip', 'decision_fusion', 'wfcg', 'densenet'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'decision_fusion', 'wfcg', 'resnet'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'decision_fusion', 'wfcg', 'mvc'] {'acc': 0.9872, 'f1': 0.9872}
# ['glip', 'decision_fusion', 'wfcg', 'vgg'] {'acc': 0.9872, 'f1': 0.9872}
# ['glip', 'decision_fusion', 'densenet', 'resnet'] {'acc': 0.9889, 'f1': 0.9889}
# ['glip', 'decision_fusion', 'densenet', 'mvc'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'decision_fusion', 'densenet', 'vgg'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'decision_fusion', 'resnet', 'mvc'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'decision_fusion', 'resnet', 'vgg'] {'acc': 0.9856, 'f1': 0.9856}
# ['glip', 'decision_fusion', 'mvc', 'vgg'] {'acc': 0.985, 'f1': 0.985}
# ['glip', 'wfcg', 'densenet', 'resnet'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'wfcg', 'densenet', 'mvc'] {'acc': 0.9889, 'f1': 0.9889}
# ['glip', 'wfcg', 'densenet', 'vgg'] {'acc': 0.9889, 'f1': 0.9889}
# ['glip', 'wfcg', 'resnet', 'mvc'] {'acc': 0.9856, 'f1': 0.9856}
# ['glip', 'wfcg', 'resnet', 'vgg'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'wfcg', 'mvc', 'vgg'] {'acc': 0.9867, 'f1': 0.9867}
# ['glip', 'densenet', 'resnet', 'mvc'] {'acc': 0.9872, 'f1': 0.9872}
# ['glip', 'densenet', 'resnet', 'vgg'] {'acc': 0.985, 'f1': 0.985}
# ['glip', 'densenet', 'mvc', 'vgg'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'resnet', 'mvc', 'vgg'] {'acc': 0.9867, 'f1': 0.9867}
# ['point_fusion', 'vit', 'decision_fusion', 'wfcg'] {'acc': 0.9872, 'f1': 0.9872}
# ['point_fusion', 'vit', 'decision_fusion', 'densenet'] {'acc': 0.9883, 'f1': 0.9883}
# ['point_fusion', 'vit', 'decision_fusion', 'resnet'] {'acc': 0.9883, 'f1': 0.9883}
# ['point_fusion', 'vit', 'decision_fusion', 'mvc'] {'acc': 0.9872, 'f1': 0.9872}
# ['point_fusion', 'vit', 'decision_fusion', 'vgg'] {'acc': 0.9872, 'f1': 0.9872}
# ['point_fusion', 'vit', 'wfcg', 'densenet'] {'acc': 0.9872, 'f1': 0.9872}
# ['point_fusion', 'vit', 'wfcg', 'resnet'] {'acc': 0.9872, 'f1': 0.9872}
# ['point_fusion', 'vit', 'wfcg', 'mvc'] {'acc': 0.9867, 'f1': 0.9867}
# ['point_fusion', 'vit', 'wfcg', 'vgg'] {'acc': 0.9867, 'f1': 0.9867}
# ['point_fusion', 'vit', 'densenet', 'resnet'] {'acc': 0.9883, 'f1': 0.9883}
# ['point_fusion', 'vit', 'densenet', 'mvc'] {'acc': 0.9872, 'f1': 0.9872}
# ['point_fusion', 'vit', 'densenet', 'vgg'] {'acc': 0.9872, 'f1': 0.9872}
# ['point_fusion', 'vit', 'resnet', 'mvc'] {'acc': 0.9867, 'f1': 0.9867}
# ['point_fusion', 'vit', 'resnet', 'vgg'] {'acc': 0.9861, 'f1': 0.9861}
# ['point_fusion', 'vit', 'mvc', 'vgg'] {'acc': 0.9856, 'f1': 0.9856}
# ['point_fusion', 'decision_fusion', 'wfcg', 'densenet'] {'acc': 0.9872, 'f1': 0.9872}
# ['point_fusion', 'decision_fusion', 'wfcg', 'resnet'] {'acc': 0.9878, 'f1': 0.9878}
# ['point_fusion', 'decision_fusion', 'wfcg', 'mvc'] {'acc': 0.9867, 'f1': 0.9867}
# ['point_fusion', 'decision_fusion', 'wfcg', 'vgg'] {'acc': 0.9867, 'f1': 0.9867}
# ['point_fusion', 'decision_fusion', 'densenet', 'resnet'] {'acc': 0.9894, 'f1': 0.9894}
# ['point_fusion', 'decision_fusion', 'densenet', 'mvc'] {'acc': 0.9889, 'f1': 0.9889}
# ['point_fusion', 'decision_fusion', 'densenet', 'vgg'] {'acc': 0.9867, 'f1': 0.9867}
# ['point_fusion', 'decision_fusion', 'resnet', 'mvc'] {'acc': 0.9878, 'f1': 0.9878}
# ['point_fusion', 'decision_fusion', 'resnet', 'vgg'] {'acc': 0.9867, 'f1': 0.9867}
# ['point_fusion', 'decision_fusion', 'mvc', 'vgg'] {'acc': 0.9872, 'f1': 0.9872}
# ['point_fusion', 'wfcg', 'densenet', 'resnet'] {'acc': 0.9872, 'f1': 0.9872}
# ['point_fusion', 'wfcg', 'densenet', 'mvc'] {'acc': 0.9878, 'f1': 0.9878}
# ['point_fusion', 'wfcg', 'densenet', 'vgg'] {'acc': 0.9867, 'f1': 0.9867}
# ['point_fusion', 'wfcg', 'resnet', 'mvc'] {'acc': 0.9867, 'f1': 0.9867}
# ['point_fusion', 'wfcg', 'resnet', 'vgg'] {'acc': 0.9856, 'f1': 0.9856}
# ['point_fusion', 'wfcg', 'mvc', 'vgg'] {'acc': 0.9861, 'f1': 0.9861}
# ['point_fusion', 'densenet', 'resnet', 'mvc'] {'acc': 0.9867, 'f1': 0.9867}
# ['point_fusion', 'densenet', 'resnet', 'vgg'] {'acc': 0.9856, 'f1': 0.9856}
# ['point_fusion', 'densenet', 'mvc', 'vgg'] {'acc': 0.9872, 'f1': 0.9872}
# ['point_fusion', 'resnet', 'mvc', 'vgg'] {'acc': 0.9856, 'f1': 0.9856}
# ['vit', 'decision_fusion', 'wfcg', 'densenet'] {'acc': 0.9872, 'f1': 0.9872}
# ['vit', 'decision_fusion', 'wfcg', 'resnet'] {'acc': 0.9867, 'f1': 0.9867}
# ['vit', 'decision_fusion', 'wfcg', 'mvc'] {'acc': 0.9861, 'f1': 0.9861}
# ['vit', 'decision_fusion', 'wfcg', 'vgg'] {'acc': 0.9861, 'f1': 0.9861}
# ['vit', 'decision_fusion', 'densenet', 'resnet'] {'acc': 0.9889, 'f1': 0.9889}
# ['vit', 'decision_fusion', 'densenet', 'mvc'] {'acc': 0.9872, 'f1': 0.9872}
# ['vit', 'decision_fusion', 'densenet', 'vgg'] {'acc': 0.9844, 'f1': 0.9844}
# ['vit', 'decision_fusion', 'resnet', 'mvc'] {'acc': 0.9867, 'f1': 0.9867}
# ['vit', 'decision_fusion', 'resnet', 'vgg'] {'acc': 0.9861, 'f1': 0.9861}
# ['vit', 'decision_fusion', 'mvc', 'vgg'] {'acc': 0.9833, 'f1': 0.9833}
# ['vit', 'wfcg', 'densenet', 'resnet'] {'acc': 0.9872, 'f1': 0.9872}
# ['vit', 'wfcg', 'densenet', 'mvc'] {'acc': 0.9856, 'f1': 0.9856}
# ['vit', 'wfcg', 'densenet', 'vgg'] {'acc': 0.9867, 'f1': 0.9867}
# ['vit', 'wfcg', 'resnet', 'mvc'] {'acc': 0.9861, 'f1': 0.9861}
# ['vit', 'wfcg', 'resnet', 'vgg'] {'acc': 0.9878, 'f1': 0.9878}
# ['vit', 'wfcg', 'mvc', 'vgg'] {'acc': 0.9856, 'f1': 0.9856}
# ['vit', 'densenet', 'resnet', 'mvc'] {'acc': 0.9861, 'f1': 0.9861}
# ['vit', 'densenet', 'resnet', 'vgg'] {'acc': 0.9861, 'f1': 0.9861}
# ['vit', 'densenet', 'mvc', 'vgg'] {'acc': 0.9844, 'f1': 0.9845}
# ['vit', 'resnet', 'mvc', 'vgg'] {'acc': 0.985, 'f1': 0.985}
# ['decision_fusion', 'wfcg', 'densenet', 'resnet'] {'acc': 0.9867, 'f1': 0.9867}
# ['decision_fusion', 'wfcg', 'densenet', 'mvc'] {'acc': 0.9872, 'f1': 0.9872}
# ['decision_fusion', 'wfcg', 'densenet', 'vgg'] {'acc': 0.9844, 'f1': 0.9845}
# ['decision_fusion', 'wfcg', 'resnet', 'mvc'] {'acc': 0.9861, 'f1': 0.9861}
# ['decision_fusion', 'wfcg', 'resnet', 'vgg'] {'acc': 0.9856, 'f1': 0.9856}
# ['decision_fusion', 'wfcg', 'mvc', 'vgg'] {'acc': 0.9844, 'f1': 0.9845}
# ['decision_fusion', 'densenet', 'resnet', 'mvc'] {'acc': 0.9867, 'f1': 0.9867}
# ['decision_fusion', 'densenet', 'resnet', 'vgg'] {'acc': 0.9856, 'f1': 0.9856}
# ['decision_fusion', 'densenet', 'mvc', 'vgg'] {'acc': 0.9861, 'f1': 0.9861}
# ['decision_fusion', 'resnet', 'mvc', 'vgg'] {'acc': 0.985, 'f1': 0.985}
# ['wfcg', 'densenet', 'resnet', 'mvc'] {'acc': 0.9889, 'f1': 0.9889}
# ['wfcg', 'densenet', 'resnet', 'vgg'] {'acc': 0.9861, 'f1': 0.9861}
# ['wfcg', 'densenet', 'mvc', 'vgg'] {'acc': 0.9867, 'f1': 0.9867}
# ['wfcg', 'resnet', 'mvc', 'vgg'] {'acc': 0.9856, 'f1': 0.9856}
# ['densenet', 'resnet', 'mvc', 'vgg'] {'acc': 0.9828, 'f1': 0.9828}
# ['glip', 'point_fusion', 'vit', 'decision_fusion', 'wfcg'] {'acc': 0.9872, 'f1': 0.9872}
# ['glip', 'point_fusion', 'vit', 'decision_fusion', 'densenet'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'point_fusion', 'vit', 'decision_fusion', 'resnet'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'point_fusion', 'vit', 'decision_fusion', 'mvc'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'point_fusion', 'vit', 'decision_fusion', 'vgg'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'point_fusion', 'vit', 'wfcg', 'densenet'] {'acc': 0.9889, 'f1': 0.9889}
# ['glip', 'point_fusion', 'vit', 'wfcg', 'resnet'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'point_fusion', 'vit', 'wfcg', 'mvc'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'point_fusion', 'vit', 'wfcg', 'vgg'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'point_fusion', 'vit', 'densenet', 'resnet'] {'acc': 0.9889, 'f1': 0.9889}
# ['glip', 'point_fusion', 'vit', 'densenet', 'mvc'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'point_fusion', 'vit', 'densenet', 'vgg'] {'acc': 0.9894, 'f1': 0.9894}
# ['glip', 'point_fusion', 'vit', 'resnet', 'mvc'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'point_fusion', 'vit', 'resnet', 'vgg'] {'acc': 0.9889, 'f1': 0.9889}
# ['glip', 'point_fusion', 'vit', 'mvc', 'vgg'] {'acc': 0.9872, 'f1': 0.9872}
# ['glip', 'point_fusion', 'decision_fusion', 'wfcg', 'densenet'] {'acc': 0.9889, 'f1': 0.9889}
# ['glip', 'point_fusion', 'decision_fusion', 'wfcg', 'resnet'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'point_fusion', 'decision_fusion', 'wfcg', 'mvc'] {'acc': 0.9872, 'f1': 0.9872}
# ['glip', 'point_fusion', 'decision_fusion', 'wfcg', 'vgg'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'point_fusion', 'decision_fusion', 'densenet', 'resnet'] {'acc': 0.9894, 'f1': 0.9895}
# ['glip', 'point_fusion', 'decision_fusion', 'densenet', 'mvc'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'point_fusion', 'decision_fusion', 'densenet', 'vgg'] {'acc': 0.9889, 'f1': 0.9889}
# ['glip', 'point_fusion', 'decision_fusion', 'resnet', 'mvc'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'point_fusion', 'decision_fusion', 'resnet', 'vgg'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'point_fusion', 'decision_fusion', 'mvc', 'vgg'] {'acc': 0.9872, 'f1': 0.9872}
# ['glip', 'point_fusion', 'wfcg', 'densenet', 'resnet'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'point_fusion', 'wfcg', 'densenet', 'mvc'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'point_fusion', 'wfcg', 'densenet', 'vgg'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'point_fusion', 'wfcg', 'resnet', 'mvc'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'point_fusion', 'wfcg', 'resnet', 'vgg'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'point_fusion', 'wfcg', 'mvc', 'vgg'] {'acc': 0.9872, 'f1': 0.9872}
# ['glip', 'point_fusion', 'densenet', 'resnet', 'mvc'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'point_fusion', 'densenet', 'resnet', 'vgg'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'point_fusion', 'densenet', 'mvc', 'vgg'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'point_fusion', 'resnet', 'mvc', 'vgg'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'vit', 'decision_fusion', 'wfcg', 'densenet'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'vit', 'decision_fusion', 'wfcg', 'resnet'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'vit', 'decision_fusion', 'wfcg', 'mvc'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'vit', 'decision_fusion', 'wfcg', 'vgg'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'vit', 'decision_fusion', 'densenet', 'resnet'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'vit', 'decision_fusion', 'densenet', 'mvc'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'vit', 'decision_fusion', 'densenet', 'vgg'] {'acc': 0.9894, 'f1': 0.9895}
# ['glip', 'vit', 'decision_fusion', 'resnet', 'mvc'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'vit', 'decision_fusion', 'resnet', 'vgg'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'vit', 'decision_fusion', 'mvc', 'vgg'] {'acc': 0.9867, 'f1': 0.9867}
# ['glip', 'vit', 'wfcg', 'densenet', 'resnet'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'vit', 'wfcg', 'densenet', 'mvc'] {'acc': 0.9872, 'f1': 0.9872}
# ['glip', 'vit', 'wfcg', 'densenet', 'vgg'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'vit', 'wfcg', 'resnet', 'mvc'] {'acc': 0.9872, 'f1': 0.9872}
# ['glip', 'vit', 'wfcg', 'resnet', 'vgg'] {'acc': 0.9872, 'f1': 0.9872}
# ['glip', 'vit', 'wfcg', 'mvc', 'vgg'] {'acc': 0.9861, 'f1': 0.9861}
# ['glip', 'vit', 'densenet', 'resnet', 'mvc'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'vit', 'densenet', 'resnet', 'vgg'] {'acc': 0.9872, 'f1': 0.9872}
# ['glip', 'vit', 'densenet', 'mvc', 'vgg'] {'acc': 0.9872, 'f1': 0.9872}
# ['glip', 'vit', 'resnet', 'mvc', 'vgg'] {'acc': 0.9867, 'f1': 0.9867}
# ['glip', 'decision_fusion', 'wfcg', 'densenet', 'resnet'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'decision_fusion', 'wfcg', 'densenet', 'mvc'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'decision_fusion', 'wfcg', 'densenet', 'vgg'] {'acc': 0.9889, 'f1': 0.9889}
# ['glip', 'decision_fusion', 'wfcg', 'resnet', 'mvc'] {'acc': 0.9872, 'f1': 0.9872}
# ['glip', 'decision_fusion', 'wfcg', 'resnet', 'vgg'] {'acc': 0.9867, 'f1': 0.9867}
# ['glip', 'decision_fusion', 'wfcg', 'mvc', 'vgg'] {'acc': 0.9861, 'f1': 0.9861}
# ['glip', 'decision_fusion', 'densenet', 'resnet', 'mvc'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'decision_fusion', 'densenet', 'resnet', 'vgg'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'decision_fusion', 'densenet', 'mvc', 'vgg'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'decision_fusion', 'resnet', 'mvc', 'vgg'] {'acc': 0.9872, 'f1': 0.9872}
# ['glip', 'wfcg', 'densenet', 'resnet', 'mvc'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'wfcg', 'densenet', 'resnet', 'vgg'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'wfcg', 'densenet', 'mvc', 'vgg'] {'acc': 0.9872, 'f1': 0.9872}
# ['glip', 'wfcg', 'resnet', 'mvc', 'vgg'] {'acc': 0.9867, 'f1': 0.9867}
# ['glip', 'densenet', 'resnet', 'mvc', 'vgg'] {'acc': 0.9878, 'f1': 0.9878}
# ['point_fusion', 'vit', 'decision_fusion', 'wfcg', 'densenet'] {'acc': 0.9878, 'f1': 0.9878}
# ['point_fusion', 'vit', 'decision_fusion', 'wfcg', 'resnet'] {'acc': 0.9872, 'f1': 0.9872}
# ['point_fusion', 'vit', 'decision_fusion', 'wfcg', 'mvc'] {'acc': 0.9872, 'f1': 0.9872}
# ['point_fusion', 'vit', 'decision_fusion', 'wfcg', 'vgg'] {'acc': 0.9872, 'f1': 0.9872}
# ['point_fusion', 'vit', 'decision_fusion', 'densenet', 'resnet'] {'acc': 0.9889, 'f1': 0.9889}
# ['point_fusion', 'vit', 'decision_fusion', 'densenet', 'mvc'] {'acc': 0.9878, 'f1': 0.9878}
# ['point_fusion', 'vit', 'decision_fusion', 'densenet', 'vgg'] {'acc': 0.9878, 'f1': 0.9878}
# ['point_fusion', 'vit', 'decision_fusion', 'resnet', 'mvc'] {'acc': 0.9878, 'f1': 0.9878}
# ['point_fusion', 'vit', 'decision_fusion', 'resnet', 'vgg'] {'acc': 0.9883, 'f1': 0.9883}
# ['point_fusion', 'vit', 'decision_fusion', 'mvc', 'vgg'] {'acc': 0.9872, 'f1': 0.9872}
# ['point_fusion', 'vit', 'wfcg', 'densenet', 'resnet'] {'acc': 0.9878, 'f1': 0.9878}
# ['point_fusion', 'vit', 'wfcg', 'densenet', 'mvc'] {'acc': 0.9867, 'f1': 0.9867}
# ['point_fusion', 'vit', 'wfcg', 'densenet', 'vgg'] {'acc': 0.9872, 'f1': 0.9872}
# ['point_fusion', 'vit', 'wfcg', 'resnet', 'mvc'] {'acc': 0.9872, 'f1': 0.9872}
# ['point_fusion', 'vit', 'wfcg', 'resnet', 'vgg'] {'acc': 0.9872, 'f1': 0.9872}
# ['point_fusion', 'vit', 'wfcg', 'mvc', 'vgg'] {'acc': 0.9867, 'f1': 0.9867}
# ['point_fusion', 'vit', 'densenet', 'resnet', 'mvc'] {'acc': 0.9878, 'f1': 0.9878}
# ['point_fusion', 'vit', 'densenet', 'resnet', 'vgg'] {'acc': 0.9872, 'f1': 0.9872}
# ['point_fusion', 'vit', 'densenet', 'mvc', 'vgg'] {'acc': 0.9878, 'f1': 0.9878}
# ['point_fusion', 'vit', 'resnet', 'mvc', 'vgg'] {'acc': 0.9878, 'f1': 0.9878}
# ['point_fusion', 'decision_fusion', 'wfcg', 'densenet', 'resnet'] {'acc': 0.9878, 'f1': 0.9878}
# ['point_fusion', 'decision_fusion', 'wfcg', 'densenet', 'mvc'] {'acc': 0.9872, 'f1': 0.9872}
# ['point_fusion', 'decision_fusion', 'wfcg', 'densenet', 'vgg'] {'acc': 0.9872, 'f1': 0.9872}
# ['point_fusion', 'decision_fusion', 'wfcg', 'resnet', 'mvc'] {'acc': 0.9872, 'f1': 0.9872}
# ['point_fusion', 'decision_fusion', 'wfcg', 'resnet', 'vgg'] {'acc': 0.9872, 'f1': 0.9872}
# ['point_fusion', 'decision_fusion', 'wfcg', 'mvc', 'vgg'] {'acc': 0.9867, 'f1': 0.9867}
# ['point_fusion', 'decision_fusion', 'densenet', 'resnet', 'mvc'] {'acc': 0.9883, 'f1': 0.9883}
# ['point_fusion', 'decision_fusion', 'densenet', 'resnet', 'vgg'] {'acc': 0.9867, 'f1': 0.9867}
# ['point_fusion', 'decision_fusion', 'densenet', 'mvc', 'vgg'] {'acc': 0.9872, 'f1': 0.9872}
# ['point_fusion', 'decision_fusion', 'resnet', 'mvc', 'vgg'] {'acc': 0.9878, 'f1': 0.9878}
# ['point_fusion', 'wfcg', 'densenet', 'resnet', 'mvc'] {'acc': 0.9878, 'f1': 0.9878}
# ['point_fusion', 'wfcg', 'densenet', 'resnet', 'vgg'] {'acc': 0.9872, 'f1': 0.9872}
# ['point_fusion', 'wfcg', 'densenet', 'mvc', 'vgg'] {'acc': 0.9867, 'f1': 0.9867}
# ['point_fusion', 'wfcg', 'resnet', 'mvc', 'vgg'] {'acc': 0.9878, 'f1': 0.9878}
# ['point_fusion', 'densenet', 'resnet', 'mvc', 'vgg'] {'acc': 0.9872, 'f1': 0.9872}
# ['vit', 'decision_fusion', 'wfcg', 'densenet', 'resnet'] {'acc': 0.9867, 'f1': 0.9867}
# ['vit', 'decision_fusion', 'wfcg', 'densenet', 'mvc'] {'acc': 0.9867, 'f1': 0.9867}
# ['vit', 'decision_fusion', 'wfcg', 'densenet', 'vgg'] {'acc': 0.9861, 'f1': 0.9861}
# ['vit', 'decision_fusion', 'wfcg', 'resnet', 'mvc'] {'acc': 0.9872, 'f1': 0.9872}
# ['vit', 'decision_fusion', 'wfcg', 'resnet', 'vgg'] {'acc': 0.9861, 'f1': 0.9861}
# ['vit', 'decision_fusion', 'wfcg', 'mvc', 'vgg'] {'acc': 0.9867, 'f1': 0.9867}
# ['vit', 'decision_fusion', 'densenet', 'resnet', 'mvc'] {'acc': 0.9872, 'f1': 0.9872}
# ['vit', 'decision_fusion', 'densenet', 'resnet', 'vgg'] {'acc': 0.9872, 'f1': 0.9872}
# ['vit', 'decision_fusion', 'densenet', 'mvc', 'vgg'] {'acc': 0.9867, 'f1': 0.9867}
# ['vit', 'decision_fusion', 'resnet', 'mvc', 'vgg'] {'acc': 0.9867, 'f1': 0.9867}
# ['vit', 'wfcg', 'densenet', 'resnet', 'mvc'] {'acc': 0.9867, 'f1': 0.9867}
# ['vit', 'wfcg', 'densenet', 'resnet', 'vgg'] {'acc': 0.9867, 'f1': 0.9867}
# ['vit', 'wfcg', 'densenet', 'mvc', 'vgg'] {'acc': 0.9861, 'f1': 0.9861}
# ['vit', 'wfcg', 'resnet', 'mvc', 'vgg'] {'acc': 0.9861, 'f1': 0.9861}
# ['vit', 'densenet', 'resnet', 'mvc', 'vgg'] {'acc': 0.9867, 'f1': 0.9867}
# ['decision_fusion', 'wfcg', 'densenet', 'resnet', 'mvc'] {'acc': 0.9867, 'f1': 0.9867}
# ['decision_fusion', 'wfcg', 'densenet', 'resnet', 'vgg'] {'acc': 0.9872, 'f1': 0.9872}
# ['decision_fusion', 'wfcg', 'densenet', 'mvc', 'vgg'] {'acc': 0.9861, 'f1': 0.9861}
# ['decision_fusion', 'wfcg', 'resnet', 'mvc', 'vgg'] {'acc': 0.9861, 'f1': 0.9861}
# ['decision_fusion', 'densenet', 'resnet', 'mvc', 'vgg'] {'acc': 0.9872, 'f1': 0.9872}
# ['wfcg', 'densenet', 'resnet', 'mvc', 'vgg'] {'acc': 0.9867, 'f1': 0.9867}
# ['glip', 'point_fusion', 'vit', 'decision_fusion', 'wfcg', 'densenet'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'point_fusion', 'vit', 'decision_fusion', 'wfcg', 'resnet'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'point_fusion', 'vit', 'decision_fusion', 'wfcg', 'mvc'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'point_fusion', 'vit', 'decision_fusion', 'wfcg', 'vgg'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'point_fusion', 'vit', 'decision_fusion', 'densenet', 'resnet'] {'acc': 0.9889, 'f1': 0.9889}
# ['glip', 'point_fusion', 'vit', 'decision_fusion', 'densenet', 'mvc'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'point_fusion', 'vit', 'decision_fusion', 'densenet', 'vgg'] {'acc': 0.9889, 'f1': 0.9889}
# ['glip', 'point_fusion', 'vit', 'decision_fusion', 'resnet', 'mvc'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'point_fusion', 'vit', 'decision_fusion', 'resnet', 'vgg'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'point_fusion', 'vit', 'decision_fusion', 'mvc', 'vgg'] {'acc': 0.9872, 'f1': 0.9872}
# ['glip', 'point_fusion', 'vit', 'wfcg', 'densenet', 'resnet'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'point_fusion', 'vit', 'wfcg', 'densenet', 'mvc'] {'acc': 0.9872, 'f1': 0.9872}
# ['glip', 'point_fusion', 'vit', 'wfcg', 'densenet', 'vgg'] {'acc': 0.9894, 'f1': 0.9894}
# ['glip', 'point_fusion', 'vit', 'wfcg', 'resnet', 'mvc'] {'acc': 0.9872, 'f1': 0.9872}
# ['glip', 'point_fusion', 'vit', 'wfcg', 'resnet', 'vgg'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'point_fusion', 'vit', 'wfcg', 'mvc', 'vgg'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'point_fusion', 'vit', 'densenet', 'resnet', 'mvc'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'point_fusion', 'vit', 'densenet', 'resnet', 'vgg'] {'acc': 0.9889, 'f1': 0.9889}
# ['glip', 'point_fusion', 'vit', 'densenet', 'mvc', 'vgg'] {'acc': 0.9889, 'f1': 0.9889}
# ['glip', 'point_fusion', 'vit', 'resnet', 'mvc', 'vgg'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'point_fusion', 'decision_fusion', 'wfcg', 'densenet', 'resnet'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'point_fusion', 'decision_fusion', 'wfcg', 'densenet', 'mvc'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'point_fusion', 'decision_fusion', 'wfcg', 'densenet', 'vgg'] {'acc': 0.9872, 'f1': 0.9872}
# ['glip', 'point_fusion', 'decision_fusion', 'wfcg', 'resnet', 'mvc'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'point_fusion', 'decision_fusion', 'wfcg', 'resnet', 'vgg'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'point_fusion', 'decision_fusion', 'wfcg', 'mvc', 'vgg'] {'acc': 0.9867, 'f1': 0.9867}
# ['glip', 'point_fusion', 'decision_fusion', 'densenet', 'resnet', 'mvc'] {'acc': 0.9889, 'f1': 0.9889}
# ['glip', 'point_fusion', 'decision_fusion', 'densenet', 'resnet', 'vgg'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'point_fusion', 'decision_fusion', 'densenet', 'mvc', 'vgg'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'point_fusion', 'decision_fusion', 'resnet', 'mvc', 'vgg'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'point_fusion', 'wfcg', 'densenet', 'resnet', 'mvc'] {'acc': 0.9889, 'f1': 0.9889}
# ['glip', 'point_fusion', 'wfcg', 'densenet', 'resnet', 'vgg'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'point_fusion', 'wfcg', 'densenet', 'mvc', 'vgg'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'point_fusion', 'wfcg', 'resnet', 'mvc', 'vgg'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'point_fusion', 'densenet', 'resnet', 'mvc', 'vgg'] {'acc': 0.9872, 'f1': 0.9872}
# ['glip', 'vit', 'decision_fusion', 'wfcg', 'densenet', 'resnet'] {'acc': 0.9872, 'f1': 0.9872}
# ['glip', 'vit', 'decision_fusion', 'wfcg', 'densenet', 'mvc'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'vit', 'decision_fusion', 'wfcg', 'densenet', 'vgg'] {'acc': 0.9894, 'f1': 0.9894}
# ['glip', 'vit', 'decision_fusion', 'wfcg', 'resnet', 'mvc'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'vit', 'decision_fusion', 'wfcg', 'resnet', 'vgg'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'vit', 'decision_fusion', 'wfcg', 'mvc', 'vgg'] {'acc': 0.9861, 'f1': 0.9861}
# ['glip', 'vit', 'decision_fusion', 'densenet', 'resnet', 'mvc'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'vit', 'decision_fusion', 'densenet', 'resnet', 'vgg'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'vit', 'decision_fusion', 'densenet', 'mvc', 'vgg'] {'acc': 0.9872, 'f1': 0.9872}
# ['glip', 'vit', 'decision_fusion', 'resnet', 'mvc', 'vgg'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'vit', 'wfcg', 'densenet', 'resnet', 'mvc'] {'acc': 0.9872, 'f1': 0.9872}
# ['glip', 'vit', 'wfcg', 'densenet', 'resnet', 'vgg'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'vit', 'wfcg', 'densenet', 'mvc', 'vgg'] {'acc': 0.9872, 'f1': 0.9872}
# ['glip', 'vit', 'wfcg', 'resnet', 'mvc', 'vgg'] {'acc': 0.9872, 'f1': 0.9872}
# ['glip', 'vit', 'densenet', 'resnet', 'mvc', 'vgg'] {'acc': 0.9867, 'f1': 0.9867}
# ['glip', 'decision_fusion', 'wfcg', 'densenet', 'resnet', 'mvc'] {'acc': 0.9872, 'f1': 0.9872}
# ['glip', 'decision_fusion', 'wfcg', 'densenet', 'resnet', 'vgg'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'decision_fusion', 'wfcg', 'densenet', 'mvc', 'vgg'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'decision_fusion', 'wfcg', 'resnet', 'mvc', 'vgg'] {'acc': 0.9872, 'f1': 0.9872}
# ['glip', 'decision_fusion', 'densenet', 'resnet', 'mvc', 'vgg'] {'acc': 0.9867, 'f1': 0.9867}
# ['glip', 'wfcg', 'densenet', 'resnet', 'mvc', 'vgg'] {'acc': 0.9878, 'f1': 0.9878}
# ['point_fusion', 'vit', 'decision_fusion', 'wfcg', 'densenet', 'resnet'] {'acc': 0.9883, 'f1': 0.9883}
# ['point_fusion', 'vit', 'decision_fusion', 'wfcg', 'densenet', 'mvc'] {'acc': 0.9878, 'f1': 0.9878}
# ['point_fusion', 'vit', 'decision_fusion', 'wfcg', 'densenet', 'vgg'] {'acc': 0.9867, 'f1': 0.9867}
# ['point_fusion', 'vit', 'decision_fusion', 'wfcg', 'resnet', 'mvc'] {'acc': 0.9872, 'f1': 0.9872}
# ['point_fusion', 'vit', 'decision_fusion', 'wfcg', 'resnet', 'vgg'] {'acc': 0.9878, 'f1': 0.9878}
# ['point_fusion', 'vit', 'decision_fusion', 'wfcg', 'mvc', 'vgg'] {'acc': 0.9867, 'f1': 0.9867}
# ['point_fusion', 'vit', 'decision_fusion', 'densenet', 'resnet', 'mvc'] {'acc': 0.9872, 'f1': 0.9872}
# ['point_fusion', 'vit', 'decision_fusion', 'densenet', 'resnet', 'vgg'] {'acc': 0.9883, 'f1': 0.9883}
# ['point_fusion', 'vit', 'decision_fusion', 'densenet', 'mvc', 'vgg'] {'acc': 0.9883, 'f1': 0.9883}
# ['point_fusion', 'vit', 'decision_fusion', 'resnet', 'mvc', 'vgg'] {'acc': 0.9878, 'f1': 0.9878}
# ['point_fusion', 'vit', 'wfcg', 'densenet', 'resnet', 'mvc'] {'acc': 0.9872, 'f1': 0.9872}
# ['point_fusion', 'vit', 'wfcg', 'densenet', 'resnet', 'vgg'] {'acc': 0.9878, 'f1': 0.9878}
# ['point_fusion', 'vit', 'wfcg', 'densenet', 'mvc', 'vgg'] {'acc': 0.9861, 'f1': 0.9861}
# ['point_fusion', 'vit', 'wfcg', 'resnet', 'mvc', 'vgg'] {'acc': 0.9872, 'f1': 0.9872}
# ['point_fusion', 'vit', 'densenet', 'resnet', 'mvc', 'vgg'] {'acc': 0.9883, 'f1': 0.9883}
# ['point_fusion', 'decision_fusion', 'wfcg', 'densenet', 'resnet', 'mvc'] {'acc': 0.9878, 'f1': 0.9878}
# ['point_fusion', 'decision_fusion', 'wfcg', 'densenet', 'resnet', 'vgg'] {'acc': 0.9872, 'f1': 0.9872}
# ['point_fusion', 'decision_fusion', 'wfcg', 'densenet', 'mvc', 'vgg'] {'acc': 0.9872, 'f1': 0.9872}
# ['point_fusion', 'decision_fusion', 'wfcg', 'resnet', 'mvc', 'vgg'] {'acc': 0.9872, 'f1': 0.9872}
# ['point_fusion', 'decision_fusion', 'densenet', 'resnet', 'mvc', 'vgg'] {'acc': 0.9878, 'f1': 0.9878}
# ['point_fusion', 'wfcg', 'densenet', 'resnet', 'mvc', 'vgg'] {'acc': 0.9883, 'f1': 0.9883}
# ['vit', 'decision_fusion', 'wfcg', 'densenet', 'resnet', 'mvc'] {'acc': 0.9867, 'f1': 0.9867}
# ['vit', 'decision_fusion', 'wfcg', 'densenet', 'resnet', 'vgg'] {'acc': 0.9872, 'f1': 0.9872}
# ['vit', 'decision_fusion', 'wfcg', 'densenet', 'mvc', 'vgg'] {'acc': 0.9867, 'f1': 0.9867}
# ['vit', 'decision_fusion', 'wfcg', 'resnet', 'mvc', 'vgg'] {'acc': 0.9872, 'f1': 0.9872}
# ['vit', 'decision_fusion', 'densenet', 'resnet', 'mvc', 'vgg'] {'acc': 0.9872, 'f1': 0.9872}
# ['vit', 'wfcg', 'densenet', 'resnet', 'mvc', 'vgg'] {'acc': 0.9872, 'f1': 0.9872}
# ['decision_fusion', 'wfcg', 'densenet', 'resnet', 'mvc', 'vgg'] {'acc': 0.9867, 'f1': 0.9867}
# ['glip', 'point_fusion', 'vit', 'decision_fusion', 'wfcg', 'densenet', 'resnet'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'point_fusion', 'vit', 'decision_fusion', 'wfcg', 'densenet', 'mvc'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'point_fusion', 'vit', 'decision_fusion', 'wfcg', 'densenet', 'vgg'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'point_fusion', 'vit', 'decision_fusion', 'wfcg', 'resnet', 'mvc'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'point_fusion', 'vit', 'decision_fusion', 'wfcg', 'resnet', 'vgg'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'point_fusion', 'vit', 'decision_fusion', 'wfcg', 'mvc', 'vgg'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'point_fusion', 'vit', 'decision_fusion', 'densenet', 'resnet', 'mvc'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'point_fusion', 'vit', 'decision_fusion', 'densenet', 'resnet', 'vgg'] {'acc': 0.9889, 'f1': 0.9889}
# ['glip', 'point_fusion', 'vit', 'decision_fusion', 'densenet', 'mvc', 'vgg'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'point_fusion', 'vit', 'decision_fusion', 'resnet', 'mvc', 'vgg'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'point_fusion', 'vit', 'wfcg', 'densenet', 'resnet', 'mvc'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'point_fusion', 'vit', 'wfcg', 'densenet', 'resnet', 'vgg'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'point_fusion', 'vit', 'wfcg', 'densenet', 'mvc', 'vgg'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'point_fusion', 'vit', 'wfcg', 'resnet', 'mvc', 'vgg'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'point_fusion', 'vit', 'densenet', 'resnet', 'mvc', 'vgg'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'point_fusion', 'decision_fusion', 'wfcg', 'densenet', 'resnet', 'mvc'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'point_fusion', 'decision_fusion', 'wfcg', 'densenet', 'resnet', 'vgg'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'point_fusion', 'decision_fusion', 'wfcg', 'densenet', 'mvc', 'vgg'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'point_fusion', 'decision_fusion', 'wfcg', 'resnet', 'mvc', 'vgg'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'point_fusion', 'decision_fusion', 'densenet', 'resnet', 'mvc', 'vgg'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'point_fusion', 'wfcg', 'densenet', 'resnet', 'mvc', 'vgg'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'vit', 'decision_fusion', 'wfcg', 'densenet', 'resnet', 'mvc'] {'acc': 0.9872, 'f1': 0.9872}
# ['glip', 'vit', 'decision_fusion', 'wfcg', 'densenet', 'resnet', 'vgg'] {'acc': 0.9872, 'f1': 0.9872}
# ['glip', 'vit', 'decision_fusion', 'wfcg', 'densenet', 'mvc', 'vgg'] {'acc': 0.9872, 'f1': 0.9872}
# ['glip', 'vit', 'decision_fusion', 'wfcg', 'resnet', 'mvc', 'vgg'] {'acc': 0.9872, 'f1': 0.9872}
# ['glip', 'vit', 'decision_fusion', 'densenet', 'resnet', 'mvc', 'vgg'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'vit', 'wfcg', 'densenet', 'resnet', 'mvc', 'vgg'] {'acc': 0.9867, 'f1': 0.9867}
# ['glip', 'decision_fusion', 'wfcg', 'densenet', 'resnet', 'mvc', 'vgg'] {'acc': 0.9872, 'f1': 0.9872}
# ['point_fusion', 'vit', 'decision_fusion', 'wfcg', 'densenet', 'resnet', 'mvc'] {'acc': 0.9872, 'f1': 0.9872}
# ['point_fusion', 'vit', 'decision_fusion', 'wfcg', 'densenet', 'resnet', 'vgg'] {'acc': 0.9878, 'f1': 0.9878}
# ['point_fusion', 'vit', 'decision_fusion', 'wfcg', 'densenet', 'mvc', 'vgg'] {'acc': 0.9872, 'f1': 0.9872}
# ['point_fusion', 'vit', 'decision_fusion', 'wfcg', 'resnet', 'mvc', 'vgg'] {'acc': 0.9872, 'f1': 0.9872}
# ['point_fusion', 'vit', 'decision_fusion', 'densenet', 'resnet', 'mvc', 'vgg'] {'acc': 0.9883, 'f1': 0.9883}
# ['point_fusion', 'vit', 'wfcg', 'densenet', 'resnet', 'mvc', 'vgg'] {'acc': 0.9878, 'f1': 0.9878}
# ['point_fusion', 'decision_fusion', 'wfcg', 'densenet', 'resnet', 'mvc', 'vgg'] {'acc': 0.9878, 'f1': 0.9878}
# ['vit', 'decision_fusion', 'wfcg', 'densenet', 'resnet', 'mvc', 'vgg'] {'acc': 0.9861, 'f1': 0.9861}
# ['glip', 'point_fusion', 'vit', 'decision_fusion', 'wfcg', 'densenet', 'resnet', 'mvc'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'point_fusion', 'vit', 'decision_fusion', 'wfcg', 'densenet', 'resnet', 'vgg'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'point_fusion', 'vit', 'decision_fusion', 'wfcg', 'densenet', 'mvc', 'vgg'] {'acc': 0.9883, 'f1': 0.9883}
# ['glip', 'point_fusion', 'vit', 'decision_fusion', 'wfcg', 'resnet', 'mvc', 'vgg'] {'acc': 0.9872, 'f1': 0.9872}
# ['glip', 'point_fusion', 'vit', 'decision_fusion', 'densenet', 'resnet', 'mvc', 'vgg'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'point_fusion', 'vit', 'wfcg', 'densenet', 'resnet', 'mvc', 'vgg'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'point_fusion', 'decision_fusion', 'wfcg', 'densenet', 'resnet', 'mvc', 'vgg'] {'acc': 0.9872, 'f1': 0.9872}
# ['glip', 'vit', 'decision_fusion', 'wfcg', 'densenet', 'resnet', 'mvc', 'vgg'] {'acc': 0.9867, 'f1': 0.9867}
# ['point_fusion', 'vit', 'decision_fusion', 'wfcg', 'densenet', 'resnet', 'mvc', 'vgg'] {'acc': 0.9878, 'f1': 0.9878}
# ['glip', 'point_fusion', 'vit', 'decision_fusion', 'wfcg', 'densenet', 'resnet', 'mvc', 'vgg'] {'acc': 0.9878, 'f1': 0.9878}

# %% [markdown]
# 实验结果表明，某些组合中确实可能因为 voting 提高了表现。
# 但是始终没有超过 glip 的表现，与 glip 的组合往往也只是拉低表现，最多依然没有超过 99.06
# 这表明在我们的分类器范围内，有 0.94 的样本极难分类，所有分类器几乎都做错了。我们会在混淆矩阵中进一步分析它
# 想要进一步提高表现，只能尝试扩大数据增强规模 或 选用更加强大的 backbone
